# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# Data Narrative SF Department

# %% [markdown]
#  Between 1999-2017 fiscal years, San Francisco spent a total sum of $ 165,079,110,427.25 and had a total revenue of $ 176,445,022,085.97. The Police had a total spending sum of $ 7,566,056,858.25 and revenue sum $ 1,159,851,771.27.

# %%
Image('../../in_repo/images/Police_Revenue_vs_Total_Revenue.png')

# %%
Image('../../in_repo/images/Police_Spending_vs_Total_Spending.png')

# %% [markdown]
# Sum Spending of each of the Organization groups 1999-2017 Rankded Lowest to Highest
# Culture & Recreation	518,485,1799.70
# General City Responsibilities	5,638,312,478.19
# Human Welfare & Neighborhood Development	16,384,314,072.05
# Public Protection	20,160,959,486.31
# Community Health	25,392,161,701.48
# General Administration & Finance	32,238,120,002.36
# Public Works, Transportation & Commerce	60,080,390,887.16
#
#
# Sum Revenue of each of the Organization groups 1999-2017 Ranked Lowest to Highest
# Culture & Recreation	4,759,058,784.42
# Public Protection	4,979,824,436.70
# Human Welfare & Neighborhood Development	19,146,758,751.74
# Community Health	22,894,277,211.27
# General Administration & Finance	30,722,110,122.47
# General City Responsibilities	33,875,671,554.54
# Public Works, Transportation & Commerce	60,067,321,224.83

# %%
# Spending Tree Map of Organization groups
Image( '../../in_repo/images/SF_Spending_org_groups_treemap.png')

# %%
# Revenue Tree Map of Organization groups
Image( '../../in_repo/images/SF_Revenue_org_groups_treemap.png')

# %%
# Showing Revenue of Organization groups over time
Image( '../../in_repo/images/SF_Revenue_org_groups_lineplot.png')

# %%
Image( '../../in_repo/images/SF_Revenue_org_groups_heatmap.png')

# %%
# Showing Spending of Organization groups over time
Image( '../../in_repo/images/SF_Spending_org_groups_lineplot.png')

# %%
Image( '../../in_repo/images/SF_Spending_org_groups_heatmap.png')

# %% [markdown]
# If you look at the line charts you can notice an upward trend in spending, while revenue tends to stay below the spending budget and even dip towards the end.
#
# What I'm really curious about is how the Public Protection Group is producing one of the lowest revenues yet has the 4th highest spending.
#
# If you look at most of the other groups (beside General City Responsibilities) you'll see that they're ranking in Spending is similar to their ranking in Revenue. I think one of the most interesting things about this data set is how the groups compare with each other in their rankings with Spending and Revenue and since the Police Department is one third of the Spending and Revenue in Public Protection and also the single largest department I think their is a strong correlation to Public Protection to the Police.

# %%
# Police Revenue 
Image( '../../in_repo/images/Police_Revenue_in_Public_Protection.png')

# %%
# Police Spending
Image( '../../in_repo/images/Police_Spending_in_Public_Protection.png')

# %% [markdown]
# Deeper Dive into The Departments for each Organization Group

# %%
# Community Health Revenue
Image( '../../in_repo/images/Community Health_Revenue.png')

# %%
# Community Health Spending
Image( '../../in_repo/images/Community Health_Spending.png')

# %%
# Culture and Recreation Revenue
Image( '../../in_repo/images/Culture & Recreation_Revenue.png')

# %%
# Culture and Recreation Spending
Image( '../../in_repo/images/Culture & Recreation_Spending.png')

# %%
# General Administration Finance Revenue
Image( '../../in_repo/images/General Administration & Finance_Revenue.png')

# %%
# General Administration Finance Spending
Image( '../../in_repo/images/General Administration & Finance_Spending.png')

# %%
# General City Responsibilities Revenue
Image( '../../in_repo/images/General City Responsibilities_Revenue.png')

# %%
# General City Responsibilities Spending
Image( '../../in_repo/images/General City Responsibilities_Spending.png')

# %%
# Human Welfare Revenue
Image( '../../in_repo/images/Human Welfare & Neighborhood Development_Revenue.png')

# %%
# Human Welfare Spending
Image( '../../in_repo/images/Human Welfare & Neighborhood Development_Spending.png')

# %%
# Public Protection Revenue
Image( '../../in_repo/images/Public Protection_Revenue.png')

# %%
# Public Protection Spending
Image( '../../in_repo/images/Public Protection_Spending.png')

# %%
# Public Works Revenue
Image( '../../in_repo/images/Public Works, Transportation & Commerce_Revenue.png')

# %%
# Public Works Spending
Image( '../../in_repo/images/Public Works, Transportation & Commerce_Spending.png')

# %% [markdown]
# Comparing the Spending of the Police Departmnet to Incident Reports

# %%
# Police Spending vs Incident Reports
# X-axis : years 
# Y-axis red : Police Budget Spending in the Hundred Thousands
# Y-axis blue : Number of Incident Counts for each year
Image('../images/SF_Incident_Reports_vs_Budget_Data.png')

# %% [markdown]
# There has been a steady increase in Police budget over the years but very little change in Incident Reports has a whole. Since most of the Police Budget is going towards salaries in the Patrol Program this raises questions as why these reports have not gone down. Although the variance looks dramatic the lowest point is only an 11 percent decrease from the start
