# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('ggplot')

# %%
df = pd.read_csv('Spending_Revenue_cleaned.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    Fiscal Year Revenue or Spending Related Govt Units  \
# 0         1999             Revenue                 No
# 1         1999            Spending                 No
# 2         1999            Spending                 No
# 3         1999            Spending                 No
# 4         1999            Spending                 No
#
#                         Organization Group                      Department  \
# 0                        Public Protection              CRT Superior Court
# 1                        Public Protection             PDR Public Defender
# 2  Public Works, Transportation & Commerce            WTR Water Enterprise
# 3         General Administration & Finance  ADM Gen Svcs Agency-City Admin
# 4  Public Works, Transportation & Commerce          DPW GSA - Public Works
#
#                                  Program                  Character  \
# 0                   Trial Court Services       Charges For Services
# 1           Criminal And Special Defense     Non Personnel Services
# 2  Water Facilities Maintenance Projects                   Salaries
# 3           Ag Wts & Measures Inspection     Non Personnel Services
# 4                            Engineering  Mandatory Fringe Benefits
#
#                         Object                     Sub-object  \
# 0  General Government Services                     Court Fees
# 1                     Training  Training Costs Paid To Emplye
# 2      Permanent Salaries-Misc             Misc-Other Timeoff
# 3            Employee Expenses                Local Field Exp
# 4       Unemployment Insurance         Unemployment Insurance
#
#                    Fund         Fund Category     Amount
# 0          General Fund             Operating  525632.62
# 1          General Fund             Operating     425.83
# 2  Water Operating Fund   Continuing Projects   17433.51
# 3          General Fund  Work Orders/Overhead      24.00
# 4          General Fund   Continuing Projects     380.15

# %%
df_pp = df[df['Organization Group'] == 'Public Protection']
df_pp.head()
# Out:
#     Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 0          1999             Revenue                 No  Public Protection
# 1          1999            Spending                 No  Public Protection
# 13         1999            Spending                 No  Public Protection
# 21         1999            Spending                 No  Public Protection
# 26         1999            Spending                 No  Public Protection
#
#                         Department                              Program  \
# 0               CRT Superior Court                 Trial Court Services
# 1              PDR Public Defender         Criminal And Special Defense
# 13                     SHF Sheriff                      San Bruno Jails
# 21  ADM Gen Svcs Agency-City Admin  Medical Examiner - Medical Services
# 26             ADP Adult Probation     Administration - Adult Probation
#
#                  Character                       Object  \
# 0     Charges For Services  General Government Services
# 1   Non Personnel Services                     Training
# 13    Materials & Supplies                         Food
# 21                Salaries      Permanent Salaries-Misc
# 26    Materials & Supplies   Other Materials & Supplies
#
#                        Sub-object          Fund Fund Category      Amount
# 0                      Court Fees  General Fund     Operating   525632.62
# 1   Training Costs Paid To Emplye  General Fund     Operating      425.83
# 13                           Food  General Fund     Operating  1824288.05
# 21             Misc-Other Timeoff  General Fund     Operating    85662.74
# 26          Other Office Supplies  General Fund     Operating     2775.30

# %%
df_pp['Department'].value_counts()
# Out:
# SHF Sheriff                       12541
# POL Police                        12507
# FIR Fire Department                8559
# DAT District Attorney              7991
# JUV Juvenile Probation             6559
# DEM Emergency Management           4939
# ADP Adult Probation                4096
# CRT Superior Court                 3009
# PDR Public Defender                1795
# ADM Gen Svcs Agency-City Admin     1071
# Name: Department, dtype: int64

# %%
df_pp_sums = df_pp.groupby(['Department'])[['Amount']].agg('sum')
df_pp_sums.columns = ['Dep_Sums_1999-2017']
df_pp_sums
# Out:
#                                 Dep_Sums_1999-2017
# Department
# ADM Gen Svcs Agency-City Admin        3.658119e+07
# ADP Adult Probation                   3.764641e+08
# CRT Superior Court                    3.083808e+09
# DAT District Attorney                 8.784669e+08
# DEM Emergency Management              2.021800e+09
# FIR Fire Department                   6.299810e+09
# JUV Juvenile Probation                7.097967e+08
# PDR Public Defender                   4.196417e+08
# POL Police                            8.725909e+09
# SHF Sheriff                           2.588507e+09

# %%
total_sum = df_pp_sums['Dep_Sums_1999-2017'].values.sum()
total_sum
# Out:
# 25140783923.010056

# %%
police_sum = df_pp_sums[df_pp_sums.index == 'POL Police'].values.sum()
police_sum
# Out:
# 8725908629.520044

# %%
others_sum = total_sum - police_sum

# %%
slices = [df_pp_sums['Dep_Sums_1999-2017'].values]
labels = df_pp_sums.index
fig, ax1 = plt.subplots()

ax1.pie(slices, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.title('Departments Budgets of Public Protection')
plt.show()
# Out:
# <ipython-input-20-117d7af231ba>:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   ax1.pie(slices, labels=labels, autopct='%1.1f%%',

# %%
slices = [others_sum, police_sum]
labels = ['All Other Departments', 'Police']
fig, ax1 = plt.subplots()

ax1.pie(slices, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.title('Departments Budgets of Public Protection')
# plt.pie(means, labels=labels)
plt.show()

# %% [markdown]
# Focusing more on the Police Department

# %%
df.head()
# Out:
#    Fiscal Year Revenue or Spending Related Govt Units  \
# 0         1999             Revenue                 No
# 1         1999            Spending                 No
# 2         1999            Spending                 No
# 3         1999            Spending                 No
# 4         1999            Spending                 No
#
#                         Organization Group                      Department  \
# 0                        Public Protection              CRT Superior Court
# 1                        Public Protection             PDR Public Defender
# 2  Public Works, Transportation & Commerce            WTR Water Enterprise
# 3         General Administration & Finance  ADM Gen Svcs Agency-City Admin
# 4  Public Works, Transportation & Commerce          DPW GSA - Public Works
#
#                                  Program                  Character  \
# 0                   Trial Court Services       Charges For Services
# 1           Criminal And Special Defense     Non Personnel Services
# 2  Water Facilities Maintenance Projects                   Salaries
# 3           Ag Wts & Measures Inspection     Non Personnel Services
# 4                            Engineering  Mandatory Fringe Benefits
#
#                         Object                     Sub-object  \
# 0  General Government Services                     Court Fees
# 1                     Training  Training Costs Paid To Emplye
# 2      Permanent Salaries-Misc             Misc-Other Timeoff
# 3            Employee Expenses                Local Field Exp
# 4       Unemployment Insurance         Unemployment Insurance
#
#                    Fund         Fund Category     Amount
# 0          General Fund             Operating  525632.62
# 1          General Fund             Operating     425.83
# 2  Water Operating Fund   Continuing Projects   17433.51
# 3          General Fund  Work Orders/Overhead      24.00
# 4          General Fund   Continuing Projects     380.15

# %%
df_police = df[df['Department'] == 'POL Police']
df_police.head()
# Out:
#      Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 93          1999            Spending                 No  Public Protection
# 94          1999            Spending                 No  Public Protection
# 106         1999            Spending                 No  Public Protection
# 140         1999             Revenue                 No  Public Protection
# 186         1999            Spending                 No  Public Protection
#
#      Department                        Program                    Character  \
# 93   POL Police          Senior Escort Service    Mandatory Fringe Benefits
# 94   POL Police  Operations And Administration         Materials & Supplies
# 106  POL Police  Operations And Administration         Materials & Supplies
# 140  POL Police                Police Services  Intergovernmental Rev-Other
# 186  POL Police             911/Communications                     Salaries
#
#                              Object                    Sub-object  \
# 93                  Social Security  Social Sec-Medicare(HI Only)
# 94       Other Materials & Supplies                         Forms
# 106  Building & Constructn Supplies    Small Tools And Intruments
# 140   Other - Governmental Agencies   Other Local-Regional Grants
# 186                     Premium Pay            Premium Pay - Misc
#
#                        Fund        Fund Category     Amount
# 93             General Fund            Operating   10958.13
# 94             General Fund            Operating   43255.58
# 106            General Fund            Operating     991.21
# 140  Public Protection Fund  Continuing Projects    3000.00
# 186            General Fund            Operating  293054.99

# %%
df_police['Program'].value_counts()
# Out:
# Operations And Administration               3098
# Investigations                              2547
# Patrol                                      2483
# Office Of Citizen Complaints                 952
# Work Order Services                          790
# Airport Police                               469
# Crime Control                                279
# SFPD Training                                267
# Police Operations                            253
# Special Operations                           210
# SFPD-Recruitment And Examination Program     191
# Senior Escort Service                        186
# No Program Defined                           123
# Fingerprint                                  123
# 911/Communications                            92
# Narcotics Forfeiture                          92
# Vehicle Theft Abatement                       72
# Taxi Enforcement                              65
# SFPD-Crime Photo Labs-Cri                     56
# Police Services                               55
# Capital Programs & Construction               27
# Federal Transportation Security               18
# Planning & Development                        16
# Special Investigations                        13
# Office Of Emergency Service                    6
# Safe Contract                                  6
# Capital Projects                               5
# Juvenile Bureau                                4
# Departmental Fund Transfer                     4
# Police                                         3
# Management Control                             1
# City Capital Projects                          1
# Name: Program, dtype: int64

# %%
df_police['Character'].value_counts()
# Out:
# Non Personnel Services            3069
# Mandatory Fringe Benefits         2751
# Salaries                          2010
# Materials & Supplies              1750
# Services Of Other Depts            944
# Capital Outlay                     421
# Charges For Services               416
# Expenditure Recovery               349
# Intergovernmental Rev-State        159
# Intergovernmental Rev-Federal      143
# Transfer Adjustments-Uses           92
# Transfer Adjustments-Sources        92
# Other Revenues                      71
# Fines; Forfeitures & Penalties      64
# Interest & Investment Income        60
# Licenses; Permits & Franchises      32
# Operating Transfers Out             27
# Overhead and Allocations            15
# Operating Transfers In              15
# Intergovernmental Rev-Other          8
# City Grant Programs                  7
# Other Support&Care Of Persons        7
# Intrafund Transfers Out              3
# Intrafund Transfers In               2
# Name: Character, dtype: int64

# %%
df_pol_programs = df_police.groupby(['Program'])[['Amount']].agg('sum')
df_pol_programs
# Out:
#                                                 Amount
# Program
# 911/Communications                        1.664207e+07
# Airport Police                            6.566977e+08
# Capital Programs & Construction           2.440704e+06
# Capital Projects                         -2.579930e+05
# City Capital Projects                     6.630000e+02
# Crime Control                             3.557957e+08
# Departmental Fund Transfer                1.152487e+06
# Federal Transportation Security           1.101668e+07
# Fingerprint                               1.365089e+07
# Investigations                            1.202001e+09
# Juvenile Bureau                           1.412520e+05
# Management Control                        2.037400e+02
# Narcotics Forfeiture                      9.383254e+06
# No Program Defined                       -1.136369e+06
# Office Of Citizen Complaints              6.965712e+07
# Office Of Emergency Service               6.506874e+05
# Operations And Administration             1.776458e+09
# Patrol                                    4.516768e+09
# Planning & Development                    1.418615e+06
# Police                                    1.472170e+04
# Police Operations                         1.864755e+07
# Police Services                           7.041563e+05
# SFPD Training                             2.141484e+07
# SFPD-Crime Photo Labs-Cri                 3.219604e+06
# SFPD-Recruitment And Examination Program  8.293078e+06
# Safe Contract                             3.656085e+06
# Senior Escort Service                     5.582116e+06
# Special Investigations                    3.528230e+04
# Special Operations                        2.028050e+07
# Taxi Enforcement                          2.793720e+06
# Vehicle Theft Abatement                   5.997742e+06
# Work Order Services                       2.788697e+06

# %%
years = df['Fiscal Year'].unique()
years
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype=int64)

# %%
df_year = []
for year in years:
    df_year.append( df_police[df_police['Fiscal Year'] == year])

# %%
df_year[0]
# Out:
#        Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 93            1999            Spending                 No  Public Protection
# 94            1999            Spending                 No  Public Protection
# 106           1999            Spending                 No  Public Protection
# 140           1999             Revenue                 No  Public Protection
# 186           1999            Spending                 No  Public Protection
# ...            ...                 ...                ...                ...
# 23416         1999             Revenue                 No  Public Protection
# 23430         1999            Spending                 No  Public Protection
# 23449         1999            Spending                 No  Public Protection
# 23514         1999            Spending                 No  Public Protection
# 23577         1999            Spending                 No  Public Protection
#
#        Department                                   Program  \
# 93     POL Police                     Senior Escort Service
# 94     POL Police             Operations And Administration
# 106    POL Police             Operations And Administration
# 140    POL Police                           Police Services
# 186    POL Police                        911/Communications
# ...           ...                                       ...
# 23416  POL Police                             SFPD Training
# 23430  POL Police                            Investigations
# 23449  POL Police              Office Of Citizen Complaints
# 23514  POL Police                        911/Communications
# 23577  POL Police  SFPD-Recruitment And Examination Program
#
#                          Character                          Object  \
# 93       Mandatory Fringe Benefits                 Social Security
# 94            Materials & Supplies      Other Materials & Supplies
# 106           Materials & Supplies  Building & Constructn Supplies
# 140    Intergovernmental Rev-Other   Other - Governmental Agencies
# 186                       Salaries                     Premium Pay
# ...                            ...                             ...
# 23416  Intergovernmental Rev-State                   State - Other
# 23430                     Salaries         Permanent Salaries-Misc
# 23449       Non Personnel Services                        Training
# 23514    Mandatory Fringe Benefits                 Social Security
# 23577    Mandatory Fringe Benefits                      Retirement
#
#                           Sub-object                    Fund  \
# 93      Social Sec-Medicare(HI Only)            General Fund
# 94                             Forms            General Fund
# 106       Small Tools And Intruments            General Fund
# 140      Other Local-Regional Grants  Public Protection Fund
# 186               Premium Pay - Misc            General Fund
# ...                              ...                     ...
# 23416         Peace Officer Training  Public Protection Fund
# 23430     Perm Salaries-Misc-Regular            General Fund
# 23449  Training Costs Paid To Emplye            General Fund
# 23514   Social Security (Oasdi & Hi)            General Fund
# 23577             Retirement Pick Up            General Fund
#
#              Fund Category       Amount
# 93               Operating     10958.13
# 94               Operating     43255.58
# 106              Operating       991.21
# 140    Continuing Projects      3000.00
# 186              Operating    293054.99
# ...                    ...          ...
# 23416  Continuing Projects    636532.68
# 23430            Operating  20665671.86
# 23449            Operating      1005.11
# 23514            Operating    450453.33
# 23577            Operating     46277.92
#
# [789 rows x 12 columns]

# %%
program_sums = []
for i in range(19):
    program_sums.append( pd.DataFrame(df_year[i].groupby('Program').Amount.agg('sum')) )
    col_year = years[i]
    program_sums[i].columns = [col_year]

# %%
df_aggregated = pd.concat(program_sums, axis=1)
df_aggregated
# Out:
#                                                   1999          2000  \
# 911/Communications                        1.616017e+07  3.923009e+05
# Airport Police                            1.806696e+07  2.112372e+07
# City Capital Projects                     6.630000e+02           NaN
# Crime Control                             8.087882e+06  1.328624e+07
# Fingerprint                               1.759181e+06  1.184828e+06
# Investigations                            3.608852e+07  3.982889e+07
# Juvenile Bureau                           2.869997e+04           NaN
# Narcotics Forfeiture                      1.278127e+06  1.375068e+06
# No Program Defined                        1.123412e+05  8.701539e+04
# Office Of Citizen Complaints              2.031358e+06  2.331155e+06
# Operations And Administration             4.110268e+07  5.329274e+07
# Patrol                                    1.566657e+08  1.763137e+08
# Police Operations                         1.270005e+05  2.106527e+05
# Police Services                           5.127350e+03  2.210561e+05
# SFPD Training                             1.490870e+06  1.380406e+06
# SFPD-Recruitment And Examination Program  1.292995e+06  1.544261e+06
# Safe Contract                             6.128916e+05  5.678608e+05
# Senior Escort Service                     1.046737e+06  1.022085e+06
# Special Investigations                    2.283230e+04  1.230000e+04
# Special Operations                        1.510179e+05  3.057295e+05
# Taxi Enforcement                          6.632115e+05  2.130509e+06
# Vehicle Theft Abatement                   9.767167e+05  9.629484e+05
# Work Order Services                       2.500000e-01  4.100000e-01
# Capital Projects                                   NaN -3.550000e+05
# Office Of Emergency Service                        NaN  2.506886e+05
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                             NaN           NaN
# Capital Programs & Construction                    NaN           NaN
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2001          2002  \
# 911/Communications                                 NaN           NaN
# Airport Police                            2.509837e+07  2.691203e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             1.436363e+07  1.333525e+07
# Fingerprint                               5.632793e+06  2.439028e+06
# Investigations                            4.049413e+07  4.397617e+07
# Juvenile Bureau                                    NaN  1.125520e+05
# Narcotics Forfeiture                      1.401866e+06  1.812013e+06
# No Program Defined                        8.111962e+04  6.887612e+04
# Office Of Citizen Complaints              2.431534e+06  2.660435e+06
# Operations And Administration             5.817293e+07  5.272834e+07
# Patrol                                    1.867238e+08  1.947401e+08
# Police Operations                         1.421203e+05  2.054134e+05
# Police Services                           8.589510e+03  1.944274e+04
# SFPD Training                             3.000961e+06  2.465500e+06
# SFPD-Recruitment And Examination Program  1.735869e+06  1.344728e+06
# Safe Contract                             5.861754e+05  6.273673e+05
# Senior Escort Service                     1.182513e+06  1.153213e+06
# Special Investigations                             NaN           NaN
# Special Operations                        1.635701e+05  2.914610e+05
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                   1.165126e+06  1.072181e+06
# Work Order Services                      -9.971300e+02 -4.500000e-01
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN  4.267280e+05
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                             NaN           NaN
# Capital Programs & Construction                    NaN           NaN
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2003          2004  \
# 911/Communications                                 NaN  7.373300e+03
# Airport Police                            2.514443e+07  2.675225e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             1.359413e+07  1.156405e+07
# Fingerprint                               1.491430e+06  1.143626e+06
# Investigations                            5.116861e+07  5.035600e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                      1.246523e+06  2.236698e+06
# No Program Defined                       -8.652862e+05  1.616479e+04
# Office Of Citizen Complaints              2.812114e+06  2.576409e+06
# Operations And Administration             4.906499e+07  5.071372e+07
# Patrol                                    1.904066e+08  1.806452e+08
# Police Operations                         4.228262e+05  5.043872e+05
# Police Services                           2.113336e+05  2.381735e+05
# SFPD Training                             1.099537e+06  1.048984e+06
# SFPD-Recruitment And Examination Program  1.383970e+06  9.912559e+05
# Safe Contract                             6.286744e+05  6.331151e+05
# Senior Escort Service                     1.172708e+06 -6.672400e+02
# Special Investigations                             NaN           NaN
# Special Operations                        9.285483e+06  1.008324e+07
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                   9.888903e+05  8.318795e+05
# Work Order Services                       3.400000e-01  1.442417e+06
# Capital Projects                                   NaN  9.700700e+04
# Office Of Emergency Service               2.733150e+05  1.266838e+05
# SFPD-Crime Photo Labs-Cri                 1.606370e+06  1.012646e+06
# Federal Transportation Security           1.114382e+07 -1.271356e+05
# Departmental Fund Transfer                         NaN  4.717784e+05
# Police                                             NaN  4.000000e+03
# Capital Programs & Construction                    NaN           NaN
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2005          2006  \
# 911/Communications                                 NaN           NaN
# Airport Police                            2.783608e+07  2.957274e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             1.397536e+07  1.913258e+07
# Fingerprint                                        NaN           NaN
# Investigations                            5.951581e+07  6.272322e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN  3.295946e+04
# No Program Defined                       -4.707332e+04 -1.389380e+03
# Office Of Citizen Complaints              2.842224e+06  3.241816e+06
# Operations And Administration             7.997473e+07  9.016354e+07
# Patrol                                    1.807123e+08  1.933768e+08
# Police Operations                         1.963627e+06  5.200662e+06
# Police Services                                    NaN           NaN
# SFPD Training                             7.312082e+05  2.235581e+05
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                     5.325390e+03  2.956400e+02
# Special Investigations                             NaN           NaN
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                       3.319500e+02 -3.230400e+02
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer               -3.350000e+02  1.152822e+06
# Police                                             NaN           NaN
# Capital Programs & Construction                    NaN           NaN
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2007          2008  \
# 911/Communications                        1.014080e+03           NaN
# Airport Police                            3.138768e+07  3.151500e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             1.989076e+07  2.538111e+07
# Fingerprint                                        NaN           NaN
# Investigations                            6.675158e+07  7.235046e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN           NaN
# No Program Defined                       -4.612200e+02  3.844646e+04
# Office Of Citizen Complaints              3.414664e+06  3.610669e+06
# Operations And Administration             9.958305e+07  1.036423e+08
# Patrol                                    2.041555e+08  2.310162e+08
# Police Operations                         8.523948e+06  8.515536e+05
# Police Services                                    NaN           NaN
# SFPD Training                             1.261132e+06  8.553904e+05
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                    -9.414000e+01           NaN
# Special Investigations                             NaN           NaN
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                      -3.600000e-01  4.200000e-01
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                 2.242915e+05 -5.043189e+04
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                    1.072170e+04           NaN
# Capital Programs & Construction                    NaN           NaN
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2009          2010  \
# 911/Communications                                 NaN           NaN
# Airport Police                            3.621037e+07  3.654462e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             2.027493e+07  2.184011e+07
# Fingerprint                                        NaN           NaN
# Investigations                            7.275879e+07  6.679826e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN           NaN
# No Program Defined                       -6.468805e+05 -7.088185e+04
# Office Of Citizen Complaints              3.932213e+06  4.324426e+06
# Operations And Administration             1.014032e+08  1.048033e+08
# Patrol                                    2.442172e+08  2.669914e+08
# Police Operations                        -1.346644e+05  8.446425e+04
# Police Services                                    NaN           NaN
# SFPD Training                             5.810559e+05  6.652244e+05
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                              NaN           NaN
# Special Investigations                             NaN  2.265000e+04
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                       1.306833e+06 -5.568182e+04
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                             NaN           NaN
# Capital Programs & Construction                    NaN  3.426190e+05
# Planning & Development                             NaN  3.290805e+05
# Management Control                                 NaN           NaN
#
#                                                   2011          2012  \
# 911/Communications                                 NaN           NaN
# Airport Police                            4.041619e+07  4.378459e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             2.079198e+07  2.249845e+07
# Fingerprint                                        NaN           NaN
# Investigations                            6.444721e+07  6.959713e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN           NaN
# No Program Defined                        2.434580e+03  1.252500e+02
# Office Of Citizen Complaints              4.134838e+06  4.478987e+06
# Operations And Administration             1.082952e+08  1.115538e+08
# Patrol                                    2.702060e+08  2.858934e+08
# Police Operations                         5.070550e+05  3.850438e+04
# Police Services                           4.335300e+02           NaN
# SFPD Training                             7.984679e+05  9.212995e+05
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                              NaN           NaN
# Special Investigations                             NaN           NaN
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                       2.859090e+03 -1.000000e-01
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                             NaN           NaN
# Capital Programs & Construction           1.302575e+06           NaN
# Planning & Development                    1.493042e+05  7.467090e+05
# Management Control                                 NaN           NaN
#
#                                                   2013          2014  \
# 911/Communications                                 NaN           NaN
# Airport Police                            4.406968e+07  4.500167e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             2.113642e+07  2.104378e+07
# Fingerprint                                        NaN           NaN
# Investigations                            7.715829e+07  7.954922e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN           NaN
# No Program Defined                        9.735000e+01  7.731384e+04
# Office Of Citizen Complaints              4.580567e+06  4.666662e+06
# Operations And Administration             1.155002e+08  1.226672e+08
# Patrol                                    3.067614e+08  3.032134e+08
# Police Operations                                  NaN           NaN
# Police Services                                    NaN           NaN
# SFPD Training                             1.089277e+06  1.007314e+06
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                              NaN           NaN
# Special Investigations                   -2.250000e+04           NaN
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                      -1.280800e+02  4.600000e-01
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN           NaN
# Police                                             NaN           NaN
# Capital Programs & Construction           1.547123e+05  1.441829e+05
# Planning & Development                    1.935208e+05           NaN
# Management Control                                 NaN           NaN
#
#                                                   2015          2016  \
# 911/Communications                        5.497209e+04  5.614840e+03
# Airport Police                            4.644925e+07  4.892530e+07
# City Capital Projects                              NaN           NaN
# Crime Control                             2.157981e+07  2.693070e+07
# Fingerprint                                        NaN           NaN
# Investigations                            7.907833e+07  8.270760e+07
# Juvenile Bureau                                    NaN           NaN
# Narcotics Forfeiture                               NaN           NaN
# No Program Defined                        8.000000e-02  2.438000e+01
# Office Of Citizen Complaints              4.818545e+06  5.062108e+06
# Operations And Administration             1.337800e+08  1.457852e+08
# Patrol                                    3.045171e+08  3.158778e+08
# Police Operations                                  NaN           NaN
# Police Services                                    NaN           NaN
# SFPD Training                             9.514229e+05  1.662666e+06
# SFPD-Recruitment And Examination Program           NaN           NaN
# Safe Contract                                      NaN           NaN
# Senior Escort Service                              NaN           NaN
# Special Investigations                             NaN           NaN
# Special Operations                                 NaN           NaN
# Taxi Enforcement                                   NaN           NaN
# Vehicle Theft Abatement                            NaN           NaN
# Work Order Services                       4.365575e-11  3.201421e-10
# Capital Projects                                   NaN           NaN
# Office Of Emergency Service                        NaN           NaN
# SFPD-Crime Photo Labs-Cri                          NaN           NaN
# Federal Transportation Security                    NaN           NaN
# Departmental Fund Transfer                         NaN -4.717784e+05
# Police                                             NaN           NaN
# Capital Programs & Construction           1.508661e+05  1.480664e+05
# Planning & Development                             NaN           NaN
# Management Control                                 NaN           NaN
#
#                                                   2017
# 911/Communications                        2.062876e+04
# Airport Police                            5.188674e+07
# City Capital Projects                              NaN
# Crime Control                             2.708857e+07
# Fingerprint                                        NaN
# Investigations                            8.665262e+07
# Juvenile Bureau                                    NaN
# Narcotics Forfeiture                               NaN
# No Program Defined                        1.164460e+04
# Office Of Citizen Complaints              5.706397e+06
# Operations And Administration             1.542313e+08
# Patrol                                    3.243342e+08
# Police Operations                                  NaN
# Police Services                                    NaN
# SFPD Training                             1.805688e+05
# SFPD-Recruitment And Examination Program           NaN
# Safe Contract                                      NaN
# Senior Escort Service                              NaN
# Special Investigations                             NaN
# Special Operations                                 NaN
# Taxi Enforcement                                   NaN
# Vehicle Theft Abatement                            NaN
# Work Order Services                       9.338614e+04
# Capital Projects                                   NaN
# Office Of Emergency Service                        NaN
# SFPD-Crime Photo Labs-Cri                          NaN
# Federal Transportation Security                    NaN
# Departmental Fund Transfer                         NaN
# Police                                             NaN
# Capital Programs & Construction           1.976820e+05
# Planning & Development                             NaN
# Management Control                        2.037400e+02

# %%
df_aggregated = df_aggregated.fillna(0)

# %%
df_aggregated
# Out:
#                                                   1999          2000  \
# 911/Communications                        1.616017e+07  3.923009e+05
# Airport Police                            1.806696e+07  2.112372e+07
# City Capital Projects                     6.630000e+02  0.000000e+00
# Crime Control                             8.087882e+06  1.328624e+07
# Fingerprint                               1.759181e+06  1.184828e+06
# Investigations                            3.608852e+07  3.982889e+07
# Juvenile Bureau                           2.869997e+04  0.000000e+00
# Narcotics Forfeiture                      1.278127e+06  1.375068e+06
# No Program Defined                        1.123412e+05  8.701539e+04
# Office Of Citizen Complaints              2.031358e+06  2.331155e+06
# Operations And Administration             4.110268e+07  5.329274e+07
# Patrol                                    1.566657e+08  1.763137e+08
# Police Operations                         1.270005e+05  2.106527e+05
# Police Services                           5.127350e+03  2.210561e+05
# SFPD Training                             1.490870e+06  1.380406e+06
# SFPD-Recruitment And Examination Program  1.292995e+06  1.544261e+06
# Safe Contract                             6.128916e+05  5.678608e+05
# Senior Escort Service                     1.046737e+06  1.022085e+06
# Special Investigations                    2.283230e+04  1.230000e+04
# Special Operations                        1.510179e+05  3.057295e+05
# Taxi Enforcement                          6.632115e+05  2.130509e+06
# Vehicle Theft Abatement                   9.767167e+05  9.629484e+05
# Work Order Services                       2.500000e-01  4.100000e-01
# Capital Projects                          0.000000e+00 -3.550000e+05
# Office Of Emergency Service               0.000000e+00  2.506886e+05
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           0.000000e+00  0.000000e+00
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2001          2002  \
# 911/Communications                        0.000000e+00  0.000000e+00
# Airport Police                            2.509837e+07  2.691203e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             1.436363e+07  1.333525e+07
# Fingerprint                               5.632793e+06  2.439028e+06
# Investigations                            4.049413e+07  4.397617e+07
# Juvenile Bureau                           0.000000e+00  1.125520e+05
# Narcotics Forfeiture                      1.401866e+06  1.812013e+06
# No Program Defined                        8.111962e+04  6.887612e+04
# Office Of Citizen Complaints              2.431534e+06  2.660435e+06
# Operations And Administration             5.817293e+07  5.272834e+07
# Patrol                                    1.867238e+08  1.947401e+08
# Police Operations                         1.421203e+05  2.054134e+05
# Police Services                           8.589510e+03  1.944274e+04
# SFPD Training                             3.000961e+06  2.465500e+06
# SFPD-Recruitment And Examination Program  1.735869e+06  1.344728e+06
# Safe Contract                             5.861754e+05  6.273673e+05
# Senior Escort Service                     1.182513e+06  1.153213e+06
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        1.635701e+05  2.914610e+05
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   1.165126e+06  1.072181e+06
# Work Order Services                      -9.971300e+02 -4.500000e-01
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  4.267280e+05
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           0.000000e+00  0.000000e+00
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2003          2004  \
# 911/Communications                        0.000000e+00  7.373300e+03
# Airport Police                            2.514443e+07  2.675225e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             1.359413e+07  1.156405e+07
# Fingerprint                               1.491430e+06  1.143626e+06
# Investigations                            5.116861e+07  5.035600e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      1.246523e+06  2.236698e+06
# No Program Defined                       -8.652862e+05  1.616479e+04
# Office Of Citizen Complaints              2.812114e+06  2.576409e+06
# Operations And Administration             4.906499e+07  5.071372e+07
# Patrol                                    1.904066e+08  1.806452e+08
# Police Operations                         4.228262e+05  5.043872e+05
# Police Services                           2.113336e+05  2.381735e+05
# SFPD Training                             1.099537e+06  1.048984e+06
# SFPD-Recruitment And Examination Program  1.383970e+06  9.912559e+05
# Safe Contract                             6.286744e+05  6.331151e+05
# Senior Escort Service                     1.172708e+06 -6.672400e+02
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        9.285483e+06  1.008324e+07
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   9.888903e+05  8.318795e+05
# Work Order Services                       3.400000e-01  1.442417e+06
# Capital Projects                          0.000000e+00  9.700700e+04
# Office Of Emergency Service               2.733150e+05  1.266838e+05
# SFPD-Crime Photo Labs-Cri                 1.606370e+06  1.012646e+06
# Federal Transportation Security           1.114382e+07 -1.271356e+05
# Departmental Fund Transfer                0.000000e+00  4.717784e+05
# Police                                    0.000000e+00  4.000000e+03
# Capital Programs & Construction           0.000000e+00  0.000000e+00
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2005          2006  \
# 911/Communications                        0.000000e+00  0.000000e+00
# Airport Police                            2.783608e+07  2.957274e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             1.397536e+07  1.913258e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            5.951581e+07  6.272322e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  3.295946e+04
# No Program Defined                       -4.707332e+04 -1.389380e+03
# Office Of Citizen Complaints              2.842224e+06  3.241816e+06
# Operations And Administration             7.997473e+07  9.016354e+07
# Patrol                                    1.807123e+08  1.933768e+08
# Police Operations                         1.963627e+06  5.200662e+06
# Police Services                           0.000000e+00  0.000000e+00
# SFPD Training                             7.312082e+05  2.235581e+05
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                     5.325390e+03  2.956400e+02
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                       3.319500e+02 -3.230400e+02
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer               -3.350000e+02  1.152822e+06
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           0.000000e+00  0.000000e+00
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2007          2008  \
# 911/Communications                        1.014080e+03  0.000000e+00
# Airport Police                            3.138768e+07  3.151500e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             1.989076e+07  2.538111e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            6.675158e+07  7.235046e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  0.000000e+00
# No Program Defined                       -4.612200e+02  3.844646e+04
# Office Of Citizen Complaints              3.414664e+06  3.610669e+06
# Operations And Administration             9.958305e+07  1.036423e+08
# Patrol                                    2.041555e+08  2.310162e+08
# Police Operations                         8.523948e+06  8.515536e+05
# Police Services                           0.000000e+00  0.000000e+00
# SFPD Training                             1.261132e+06  8.553904e+05
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                    -9.414000e+01  0.000000e+00
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                      -3.600000e-01  4.200000e-01
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 2.242915e+05 -5.043189e+04
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    1.072170e+04  0.000000e+00
# Capital Programs & Construction           0.000000e+00  0.000000e+00
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2009          2010  \
# 911/Communications                        0.000000e+00  0.000000e+00
# Airport Police                            3.621037e+07  3.654462e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             2.027493e+07  2.184011e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            7.275879e+07  6.679826e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  0.000000e+00
# No Program Defined                       -6.468805e+05 -7.088185e+04
# Office Of Citizen Complaints              3.932213e+06  4.324426e+06
# Operations And Administration             1.014032e+08  1.048033e+08
# Patrol                                    2.442172e+08  2.669914e+08
# Police Operations                        -1.346644e+05  8.446425e+04
# Police Services                           0.000000e+00  0.000000e+00
# SFPD Training                             5.810559e+05  6.652244e+05
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                     0.000000e+00  0.000000e+00
# Special Investigations                    0.000000e+00  2.265000e+04
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                       1.306833e+06 -5.568182e+04
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           0.000000e+00  3.426190e+05
# Planning & Development                    0.000000e+00  3.290805e+05
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2011          2012  \
# 911/Communications                        0.000000e+00  0.000000e+00
# Airport Police                            4.041619e+07  4.378459e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             2.079198e+07  2.249845e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            6.444721e+07  6.959713e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  0.000000e+00
# No Program Defined                        2.434580e+03  1.252500e+02
# Office Of Citizen Complaints              4.134838e+06  4.478987e+06
# Operations And Administration             1.082952e+08  1.115538e+08
# Patrol                                    2.702060e+08  2.858934e+08
# Police Operations                         5.070550e+05  3.850438e+04
# Police Services                           4.335300e+02  0.000000e+00
# SFPD Training                             7.984679e+05  9.212995e+05
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                     0.000000e+00  0.000000e+00
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                       2.859090e+03 -1.000000e-01
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           1.302575e+06  0.000000e+00
# Planning & Development                    1.493042e+05  7.467090e+05
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2013          2014  \
# 911/Communications                        0.000000e+00  0.000000e+00
# Airport Police                            4.406968e+07  4.500167e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             2.113642e+07  2.104378e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            7.715829e+07  7.954922e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  0.000000e+00
# No Program Defined                        9.735000e+01  7.731384e+04
# Office Of Citizen Complaints              4.580567e+06  4.666662e+06
# Operations And Administration             1.155002e+08  1.226672e+08
# Patrol                                    3.067614e+08  3.032134e+08
# Police Operations                         0.000000e+00  0.000000e+00
# Police Services                           0.000000e+00  0.000000e+00
# SFPD Training                             1.089277e+06  1.007314e+06
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                     0.000000e+00  0.000000e+00
# Special Investigations                   -2.250000e+04  0.000000e+00
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                      -1.280800e+02  4.600000e-01
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00  0.000000e+00
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           1.547123e+05  1.441829e+05
# Planning & Development                    1.935208e+05  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2015          2016  \
# 911/Communications                        5.497209e+04  5.614840e+03
# Airport Police                            4.644925e+07  4.892530e+07
# City Capital Projects                     0.000000e+00  0.000000e+00
# Crime Control                             2.157981e+07  2.693070e+07
# Fingerprint                               0.000000e+00  0.000000e+00
# Investigations                            7.907833e+07  8.270760e+07
# Juvenile Bureau                           0.000000e+00  0.000000e+00
# Narcotics Forfeiture                      0.000000e+00  0.000000e+00
# No Program Defined                        8.000000e-02  2.438000e+01
# Office Of Citizen Complaints              4.818545e+06  5.062108e+06
# Operations And Administration             1.337800e+08  1.457852e+08
# Patrol                                    3.045171e+08  3.158778e+08
# Police Operations                         0.000000e+00  0.000000e+00
# Police Services                           0.000000e+00  0.000000e+00
# SFPD Training                             9.514229e+05  1.662666e+06
# SFPD-Recruitment And Examination Program  0.000000e+00  0.000000e+00
# Safe Contract                             0.000000e+00  0.000000e+00
# Senior Escort Service                     0.000000e+00  0.000000e+00
# Special Investigations                    0.000000e+00  0.000000e+00
# Special Operations                        0.000000e+00  0.000000e+00
# Taxi Enforcement                          0.000000e+00  0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00  0.000000e+00
# Work Order Services                       4.365575e-11  3.201421e-10
# Capital Projects                          0.000000e+00  0.000000e+00
# Office Of Emergency Service               0.000000e+00  0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00  0.000000e+00
# Federal Transportation Security           0.000000e+00  0.000000e+00
# Departmental Fund Transfer                0.000000e+00 -4.717784e+05
# Police                                    0.000000e+00  0.000000e+00
# Capital Programs & Construction           1.508661e+05  1.480664e+05
# Planning & Development                    0.000000e+00  0.000000e+00
# Management Control                        0.000000e+00  0.000000e+00
#
#                                                   2017
# 911/Communications                        2.062876e+04
# Airport Police                            5.188674e+07
# City Capital Projects                     0.000000e+00
# Crime Control                             2.708857e+07
# Fingerprint                               0.000000e+00
# Investigations                            8.665262e+07
# Juvenile Bureau                           0.000000e+00
# Narcotics Forfeiture                      0.000000e+00
# No Program Defined                        1.164460e+04
# Office Of Citizen Complaints              5.706397e+06
# Operations And Administration             1.542313e+08
# Patrol                                    3.243342e+08
# Police Operations                         0.000000e+00
# Police Services                           0.000000e+00
# SFPD Training                             1.805688e+05
# SFPD-Recruitment And Examination Program  0.000000e+00
# Safe Contract                             0.000000e+00
# Senior Escort Service                     0.000000e+00
# Special Investigations                    0.000000e+00
# Special Operations                        0.000000e+00
# Taxi Enforcement                          0.000000e+00
# Vehicle Theft Abatement                   0.000000e+00
# Work Order Services                       9.338614e+04
# Capital Projects                          0.000000e+00
# Office Of Emergency Service               0.000000e+00
# SFPD-Crime Photo Labs-Cri                 0.000000e+00
# Federal Transportation Security           0.000000e+00
# Departmental Fund Transfer                0.000000e+00
# Police                                    0.000000e+00
# Capital Programs & Construction           1.976820e+05
# Planning & Development                    0.000000e+00
# Management Control                        2.037400e+02

# %%
df_transposed = df_aggregated.T

# %%
programs = df_transposed.columns

# %%
plt.figure(figsize=(22,10))

plt.title('Police Programs 1999-2017')
plt.xlabel('Year')
plt.ylabel('Budget')


plt.xticks(np.arange(min(np.array(df_transposed.index)), max(np.array(df_transposed.index))+1, 1.0))

for program in programs:
    plt.plot(df_transposed.index, np.array(df_transposed[program]),
         label=program)


plt.legend()
plt.show()

# %%
sum_program = np.array([])
for program in programs:
    sum_val = df_transposed[program].sum()
    sum_program = np.append(sum_program, sum_val)
sum_program
# Out:
# array([ 1.66420724e+07,  6.56697679e+08,  6.63000000e+02,  3.55795747e+08,
#         1.36508861e+07,  1.20200084e+09,  1.41251970e+05,  9.38325380e+06,
#        -1.13636873e+06,  6.96571229e+07,  1.77645831e+09,  4.51676769e+09,
#         1.86475509e+07,  7.04156340e+05,  2.14148426e+07,  8.29307808e+06,
#         3.65608466e+06,  5.58211579e+06,  3.52823000e+04,  2.02804998e+07,
#         2.79372002e+06,  5.99774239e+06,  2.78869725e+06, -2.57993000e+05,
#         6.50687420e+05,  3.21960399e+06,  1.10166819e+07,  1.15248748e+06,
#         1.47217000e+04,  2.44070371e+06,  1.41861462e+06,  2.03740000e+02])

# %%
y_pos = np.arange(len(sum_program))
program_names = np.array(df_transposed.columns)
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Budget Sums of Police Programs 1999-2017')
plt.barh(y_pos, sum_program)
plt.yticks(y_pos, program_names)
plt.xlabel('Budget Amount')
plt.ylabel('Department Name')
plt.show()

# %%
# removing the 5 largest programs from the graph to look at the other programs with less funding
largest_programs = np.array(['Patrol', 'Operations And Administration', 
                             'Investigations', 'Crime Control', 'Airport Police'])
indices = np.array([], int)
for l_program in largest_programs:
    index = int(np.where(program_names == l_program)[0])
    indices = np.append(indices, index)
indices
# Out:
# array([11, 10,  5,  3,  1])

# %%
for index in indices:
    name = program_names[index]
    amount = sum_program[index]
    print('Program Name: {}, Program Amount: {}, Index: {}'.format(name, amount, index))
# Out:
# Program Name: Patrol, Program Amount: 4516767685.160001, Index: 11
# Program Name: Operations And Administration, Program Amount: 1776458312.83, Index: 10
# Program Name: Investigations, Program Amount: 1202000842.04, Index: 5
# Program Name: Crime Control, Program Amount: 355795747.23999995, Index: 3
# Program Name: Airport Police, Program Amount: 656697679.1599998, Index: 1

# %%
smaller_programs = np.copy(program_names)
smaller_budgets = np.copy(sum_program)

# %%
smaller_programs = np.delete(smaller_programs, indices)
smaller_budgets = np.delete(smaller_budgets, indices)

# %%
y_pos = np.arange(len(smaller_budgets))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Budget Sums of Less Funded Police Programs 1999-2017')
plt.barh(y_pos, smaller_budgets)
plt.yticks(y_pos, smaller_programs)
plt.xlabel('Budget Amount')
plt.ylabel('Department Name')
plt.show()

# %%
programs_of_interest = np.array(['Office Of Citizen Complaints', 'SFPD Training', 
                                 'Special Operations', 'Police Operations', '911/Communications',
                                 'SFPD-Recruitment And Examination Program'])
indices = np.array([], int)
for i_program in programs_of_interest:
    index = np.where(program_names == i_program)
    print(program_names[index])
    print(sum_program[index])
    indices = np.append(indices, index)
indices
# Out:
# ['Office Of Citizen Complaints']
# [69657122.94999999]
# ['SFPD Training']
# [21414842.57]
# ['Special Operations']
# [20280499.75]
# ['Police Operations']
# [18647550.86]
# ['911/Communications']
# [16642072.39]
# ['SFPD-Recruitment And Examination Program']
# [8293078.08]
# array([ 9, 14, 19, 12,  0, 15], dtype=int64)

# %%
for index in indices:
    name = program_names[index]
    amount = sum_program[index]
    print('Program Name: {}, Program Amount: {}, Index: {}'.format(name, amount, index))
# Out:
# Program Name: Office Of Citizen Complaints, Program Amount: 69657122.94999999, Index: 9
# Program Name: SFPD Training, Program Amount: 21414842.570000004, Index: 14
# Program Name: Special Operations, Program Amount: 20280499.75, Index: 19
# Program Name: Police Operations, Program Amount: 18647550.86, Index: 12
# Program Name: 911/Communications, Program Amount: 16642072.39, Index: 0
# Program Name: SFPD-Recruitment And Examination Program, Program Amount: 8293078.080000001, Index: 15

# %%
# creating new datasets specialized on the programs we want to focus on
df_pol_patrol = df_police[df_police['Program'] == 'Patrol']
df_pol_spec_ops = df_police[df_police['Program'] == 'Special Operations']
df_pol_admin = df_police[df_police['Program'] == 'Operations And Administration']
df_pol_recruit = df_police[df_police['Program'] == 'SFPD-Recruitment And Examination Program']
df_pol_train = df_police[df_police['Program'] == 'SFPD Training']

# %% [markdown]
# Taking a deeper dive into the Patrol Program, since this is the most funded program of the Police

# %%
df_pol_patrol.head()
# Out:
#       Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 512          1999            Spending                 No  Public Protection
# 575          1999            Spending                 No  Public Protection
# 820          1999            Spending                 No  Public Protection
# 893          1999            Spending                 No  Public Protection
# 3529         1999            Spending                 No  Public Protection
#
#       Department Program                  Character  \
# 512   POL Police  Patrol  Mandatory Fringe Benefits
# 575   POL Police  Patrol     Non Personnel Services
# 820   POL Police  Patrol     Non Personnel Services
# 893   POL Police  Patrol  Mandatory Fringe Benefits
# 3529  POL Police  Patrol                   Salaries
#
#                           Object                     Sub-object  \
# 512              Social Security   Social Sec-Medicare(HI Only)
# 575   Profess & Specialized Svcs    Other Professional Services
# 820                     Training  Training Costs Paid To Emplye
# 893              Social Security   Social Security (Oasdi & Hi)
# 3529     Permanent Salaries-Misc            Misc-Disability Pay
#
#                         Fund        Fund Category      Amount
# 512   Public Protection Fund               Grants     1422.94
# 575             General Fund            Operating      520.80
# 820   Public Protection Fund  Continuing Projects      783.00
# 893   Public Protection Fund  Continuing Projects      584.48
# 3529            General Fund            Operating  2885683.63

# %%
df_pol_patrol['Character'].value_counts()
# Out:
# Mandatory Fringe Benefits         579
# Non Personnel Services            500
# Salaries                          442
# Materials & Supplies              373
# Services Of Other Depts           267
# Capital Outlay                     81
# Intergovernmental Rev-Federal      43
# Charges For Services               35
# Intergovernmental Rev-State        30
# Transfer Adjustments-Sources       25
# Transfer Adjustments-Uses          25
# Other Revenues                     19
# Expenditure Recovery               18
# Operating Transfers Out            12
# Interest & Investment Income       10
# Operating Transfers In              9
# Overhead and Allocations            6
# City Grant Programs                 4
# Intrafund Transfers In              2
# Licenses; Permits & Franchises      1
# Intrafund Transfers Out             1
# Intergovernmental Rev-Other         1
# Name: Character, dtype: int64

# %%
df_patrol_sums = df_pol_patrol.groupby(['Character'])[['Amount']].agg('sum')
df_patrol_sums
# Out:
#                                       Amount
# Character
# Capital Outlay                  1.280888e+07
# Charges For Services            1.872790e+07
# City Grant Programs             1.461323e+05
# Expenditure Recovery            1.441527e+07
# Interest & Investment Income    1.597164e+05
# Intergovernmental Rev-Federal   5.400883e+07
# Intergovernmental Rev-Other     4.432516e+04
# Intergovernmental Rev-State     2.038458e+08
# Intrafund Transfers In          7.909720e+05
# Intrafund Transfers Out         3.826390e+05
# Licenses; Permits & Franchises  1.137286e+05
# Mandatory Fringe Benefits       6.674038e+08
# Materials & Supplies            1.198675e+07
# Non Personnel Services          7.596486e+07
# Operating Transfers In          2.728674e+07
# Operating Transfers Out         2.811904e+07
# Other Revenues                  1.682123e+06
# Overhead and Allocations        3.659670e+03
# Salaries                        3.207815e+09
# Services Of Other Depts         2.768958e+08
# Transfer Adjustments-Sources   -4.291694e+07
# Transfer Adjustments-Uses      -4.291694e+07

# %%
df_patrol_ch = np.array(df_patrol_sums.index)

# %%
df_patrol_vals = np.array(df_patrol_sums['Amount'])

# %%
df_patrol_sums[df_patrol_sums.index == 'Mandatory Fringe Benefits']
# Out:
#                                  Amount
# Character
# Mandatory Fringe Benefits  6.674038e+08

# %%
df_pol_patrol[df_pol_patrol['Character'] == 'Salaries']['Object'].value_counts()
# Out:
# Permanent Salaries-Misc    239
# Overtime                    67
# One-Time Payments           48
# Premium Pay                 47
# Holiday Pay                 41
# Name: Object, dtype: int64

# %%
df_pol_patrol[df_pol_patrol['Character'] == 'Salaries'][['Object', 'Amount']].groupby('Object').agg('sum')
# Out:
#                                Amount
# Object
# Holiday Pay              8.025669e+07
# One-Time Payments        5.269974e+07
# Overtime                 2.187603e+08
# Permanent Salaries-Misc  2.705054e+09
# Premium Pay              1.510441e+08

# %%
df_pol_patrol
# Out:
#         Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 512            1999            Spending                 No  Public Protection
# 575            1999            Spending                 No  Public Protection
# 820            1999            Spending                 No  Public Protection
# 893            1999            Spending                 No  Public Protection
# 3529           1999            Spending                 No  Public Protection
# ...             ...                 ...                ...                ...
# 516683         2017            Spending                 No  Public Protection
# 517065         2017            Spending                 No  Public Protection
# 517353         2017            Spending                 No  Public Protection
# 517540         2017            Spending                 No  Public Protection
# 517944         2017            Spending                 No  Public Protection
#
#         Department Program                  Character  \
# 512     POL Police  Patrol  Mandatory Fringe Benefits
# 575     POL Police  Patrol     Non Personnel Services
# 820     POL Police  Patrol     Non Personnel Services
# 893     POL Police  Patrol  Mandatory Fringe Benefits
# 3529    POL Police  Patrol                   Salaries
# ...            ...     ...                        ...
# 516683  POL Police  Patrol  Mandatory Fringe Benefits
# 517065  POL Police  Patrol                   Salaries
# 517353  POL Police  Patrol  Mandatory Fringe Benefits
# 517540  POL Police  Patrol     Non Personnel Services
# 517944  POL Police  Patrol       Materials & Supplies
#
#                                 Object                     Sub-object  \
# 512                    Social Security   Social Sec-Medicare(HI Only)
# 575         Profess & Specialized Svcs    Other Professional Services
# 820                           Training  Training Costs Paid To Emplye
# 893                    Social Security   Social Security (Oasdi & Hi)
# 3529           Permanent Salaries-Misc            Misc-Disability Pay
# ...                                ...                            ...
# 516683          Unemployment Insurance         Unemployment Insurance
# 517065         Permanent Salaries-Misc     Perm Salaries-Misc-Regular
# 517353                 Social Security   Social Sec-Medicare(HI Only)
# 517540      Profess & Specialized Svcs    Other Professional Services
# 517944  Equipment Maintenance Supplies         Communication Supplies
#
#                           Fund        Fund Category        Amount
# 512     Public Protection Fund               Grants  1.422940e+03
# 575               General Fund            Operating  5.208000e+02
# 820     Public Protection Fund  Continuing Projects  7.830000e+02
# 893     Public Protection Fund  Continuing Projects  5.844800e+02
# 3529              General Fund            Operating  2.885684e+06
# ...                        ...                  ...           ...
# 516683            General Fund      Annual Projects  6.932000e+02
# 517065            General Fund            Operating  1.544654e+08
# 517353            General Fund            Operating  3.079192e+06
# 517540            General Fund            Operating  9.498440e+03
# 517944            General Fund            Operating  3.458860e+03
#
# [2483 rows x 12 columns]

# %%
y_pos = np.arange(len(df_patrol_ch))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Breakdown of Police Patrol Program 1999-2017')
plt.barh(y_pos, df_patrol_vals)
plt.yticks(y_pos, df_patrol_ch)
plt.xlabel('Budget Amount')
plt.ylabel('Character')
plt.show()

# %%
df_pol_patrol_yearly = df_pol_patrol.groupby(['Character', 'Fiscal Year'])[['Amount']].agg('sum')
df_pol_patrol_yearly
# Out:
#                                            Amount
# Character                 Fiscal Year
# Capital Outlay            1999         1216684.44
#                           2000         2225581.19
#                           2001          964572.50
#                           2002          710153.69
#                           2003          185013.64
# ...                                           ...
# Transfer Adjustments-Uses 2013        -1751959.39
#                           2014        -1720854.00
#                           2015        -1607027.37
#                           2016        -1837962.78
#                           2017        -2173960.87
#
# [275 rows x 1 columns]

# %%
# df_pol_spec_ops_ch

# %%
df_pol_spec_ops[df_pol_spec_ops['Character'] == 'Charges For Services']
# Out:
#         Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 135081         2004             Revenue                 No  Public Protection
#
#         Department             Program             Character  \
# 135081  POL Police  Special Operations  Charges For Services
#
#                                Object                   Sub-object  \
# 135081  Public Safety Service Charges  Other Public Safety Charges
#
#                 Fund Fund Category    Amount
# 135081  General Fund     Operating  11999.17

# %%
df_pol_spec_ops_ch = df_pol_spec_ops.groupby(['Character'])[['Amount']].agg('sum')
df_pol_spec_ops_ch['Amount'].values
# Out:
# array([1.82788260e+05, 1.19991700e+04, 1.78655264e+06, 4.54847070e+05,
#        8.95092030e+05, 2.00000000e+02, 1.69187206e+07, 3.03000000e+04])

# %%
y_pos = np.arange(len(df_pol_spec_ops_ch.index))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Breakdown of Police Special Ops Program 1999-2017')
plt.barh(y_pos, df_pol_spec_ops_ch['Amount'].values)
plt.yticks(y_pos, df_pol_spec_ops_ch.index)
plt.xlabel('Budget Amount')
plt.ylabel('Character')
plt.show()

# %%
df_pol_admin_ch = df_pol_admin.groupby(['Character'])[['Amount']].agg('sum')
df_pol_admin_ch
# Out:
#                                       Amount
# Character
# Capital Outlay                  4.768583e+07
# Charges For Services            6.991802e+07
# City Grant Programs             5.731230e+05
# Expenditure Recovery            2.565250e+06
# Fines; Forfeitures & Penalties  9.298113e+06
# Interest & Investment Income    5.971220e+03
# Intergovernmental Rev-Federal   7.029566e+06
# Intergovernmental Rev-Other     4.700000e+04
# Intergovernmental Rev-State     5.066407e+08
# Intrafund Transfers Out         4.233330e+05
# Licenses; Permits & Franchises  1.075598e+05
# Mandatory Fringe Benefits       1.366602e+08
# Materials & Supplies            6.624963e+07
# Non Personnel Services          8.994944e+07
# Operating Transfers In          1.672570e+05
# Operating Transfers Out         2.420048e+06
# Other Revenues                  7.503200e+02
# Other Support&Care Of Persons   3.183400e+05
# Overhead and Allocations        1.687353e+04
# Salaries                        5.851987e+08
# Services Of Other Depts         2.619999e+08
# Transfer Adjustments-Sources   -5.408632e+06
# Transfer Adjustments-Uses      -5.408632e+06

# %%
y_pos = np.arange(len(df_pol_admin_ch.index))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Breakdown of Police Administration and Operations Program 1999-2017')
plt.barh(y_pos, df_pol_admin_ch['Amount'].values)
plt.yticks(y_pos, df_pol_admin_ch.index)
plt.xlabel('Budget Amount')
plt.ylabel('Character')
plt.show()

# %%
df_pol_recruit_ch = df_pol_recruit.groupby(['Character'])[['Amount']].agg('sum')
df_pol_recruit_ch
# Out:
#                                   Amount
# Character
# Capital Outlay                  18452.60
# Expenditure Recovery           -21717.16
# Mandatory Fringe Benefits      888665.43
# Materials & Supplies           305677.10
# Non Personnel Services        2487472.08
# Overhead and Allocations           -6.53
# Salaries                      4199327.92
# Services Of Other Depts        371772.32
# Transfer Adjustments-Sources    21717.16
# Transfer Adjustments-Uses       21717.16

# %%
y_pos = np.arange(len(df_pol_recruit_ch.index))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Breakdown of Police Recruiting Program 1999-2017')
plt.barh(y_pos, df_pol_recruit_ch['Amount'].values)
plt.yticks(y_pos, df_pol_recruit_ch.index)
plt.xlabel('Budget Amount')
plt.ylabel('Character')
plt.show()

# %%
df_pol_train_ch = df_pol_train.groupby(['Character'])[['Amount']].agg('sum')
df_pol_train_ch
# Out:
#                                   Amount
# Character
# Capital Outlay                 954702.69
# Charges For Services           148743.94
# Intergovernmental Rev-State  10877961.00
# Mandatory Fringe Benefits       32406.95
# Materials & Supplies           807337.21
# Non Personnel Services        3901039.43
# Salaries                      4211198.90
# Services Of Other Depts        481452.45

# %%
y_pos = np.arange(len(df_pol_train_ch.index))
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title('Breakdown of Police Training Program 1999-2017')
plt.barh(y_pos, df_pol_train_ch['Amount'].values)
plt.yticks(y_pos, df_pol_train_ch.index)
plt.xlabel('Budget Amount')
plt.ylabel('Character')
plt.show()

# %% [markdown]
# Looking at trends of the budget data over time

# %%
df_police.head()
# Out:
#      Fiscal Year Revenue or Spending Related Govt Units Organization Group  \
# 93          1999            Spending                 No  Public Protection
# 94          1999            Spending                 No  Public Protection
# 106         1999            Spending                 No  Public Protection
# 140         1999             Revenue                 No  Public Protection
# 186         1999            Spending                 No  Public Protection
#
#      Department                        Program                    Character  \
# 93   POL Police          Senior Escort Service    Mandatory Fringe Benefits
# 94   POL Police  Operations And Administration         Materials & Supplies
# 106  POL Police  Operations And Administration         Materials & Supplies
# 140  POL Police                Police Services  Intergovernmental Rev-Other
# 186  POL Police             911/Communications                     Salaries
#
#                              Object                    Sub-object  \
# 93                  Social Security  Social Sec-Medicare(HI Only)
# 94       Other Materials & Supplies                         Forms
# 106  Building & Constructn Supplies    Small Tools And Intruments
# 140   Other - Governmental Agencies   Other Local-Regional Grants
# 186                     Premium Pay            Premium Pay - Misc
#
#                        Fund        Fund Category     Amount
# 93             General Fund            Operating   10958.13
# 94             General Fund            Operating   43255.58
# 106            General Fund            Operating     991.21
# 140  Public Protection Fund  Continuing Projects    3000.00
# 186            General Fund            Operating  293054.99

# %%
df_year = []
for index, year in enumerate(df_police['Fiscal Year'].unique()):
    df_year.append( df[df['Fiscal Year'] == year])

# %%
df_year[0].head()
# Out:
#    Fiscal Year Revenue or Spending Related Govt Units  \
# 0         1999             Revenue                 No
# 1         1999            Spending                 No
# 2         1999            Spending                 No
# 3         1999            Spending                 No
# 4         1999            Spending                 No
#
#                         Organization Group                      Department  \
# 0                        Public Protection             ADP Adult Probation
# 1                        Public Protection             PDR Public Defender
# 2  Public Works, Transportation & Commerce            WTR Water Enterprise
# 3         General Administration & Finance  ADM Gen Svcs Agency-City Admin
# 4  Public Works, Transportation & Commerce          DPW GSA - Public Works
#
#                                  Program                  Character  \
# 0                     Community Services       Charges For Services
# 1           Criminal And Special Defense     Non Personnel Services
# 2  Water Facilities Maintenance Projects                   Salaries
# 3           Ag Wts & Measures Inspection     Non Personnel Services
# 4                            Engineering  Mandatory Fringe Benefits
#
#                           Object                     Sub-object  \
# 0  Public Safety Service Charges    Other Public Safety Charges
# 1                       Training  Training Costs Paid To Emplye
# 2        Permanent Salaries-Misc             Misc-Other Timeoff
# 3              Employee Expenses                Local Field Exp
# 4         Unemployment Insurance         Unemployment Insurance
#
#                    Fund         Fund Category    Amount
# 0          General Fund             Operating  26742.00
# 1          General Fund             Operating    425.83
# 2  Water Operating Fund   Continuing Projects  17433.51
# 3          General Fund  Work Orders/Overhead     24.00
# 4          General Fund   Continuing Projects    380.15

# %%
program_sums = []
for i in range(19):
    program_sums.append( pd.DataFrame(df_year[i].groupby('Program').Amount.agg('sum')) )
    col_year = years[i]
    program_sums[i].columns = [col_year]

# %% [markdown]
# Looking at certain prorgams and as they change over time, these programs are
# -Patrol
# -Special Operations
# -Administration and Operations
# -Police Recruiting
# -Police Training

# %%
df_agg_programs=pd.concat(program_sums, axis=1)
df_agg_programs.fillna(0, inplace=True)
df_agg_programs.head()
# Out:
# C:\Users\craig\Desktop\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                      1999         2000         2001  \
# 1660 Mission Street Building   2375527.99   2303120.36   2656967.90
# 25 Van Ness Building           4750712.86   5408838.48   6159096.35
# 30 Van Ness Building                 0.00         0.00         0.00
# 311 Call Center                      0.00         0.00         0.00
# 3Com Park                     19646512.14  17023628.77  10107891.64
#
#                                      2002         2003  2004  2005  2006  \
# 1660 Mission Street Building   3050825.42         0.00   0.0   0.0   0.0
# 25 Van Ness Building           5070357.14         0.00   0.0   0.0   0.0
# 30 Van Ness Building          75113448.23         0.00   0.0   0.0   0.0
# 311 Call Center                      0.00         0.00   0.0   0.0   0.0
# 3Com Park                      8941622.16  12178551.64   0.0   0.0   0.0
#
#                                     2007        2008        2009       2010  \
# 1660 Mission Street Building        0.00        0.00        0.00        0.0
# 25 Van Ness Building                0.00        0.00        0.00        0.0
# 30 Van Ness Building                0.00        0.00        0.00        0.0
# 311 Call Center               5226796.34  7938438.63  3980095.29  4327345.5
# 3Com Park                           0.00        0.00        0.00        0.0
#
#                                     2011        2012        2013        2014  \
# 1660 Mission Street Building        0.00        0.00        0.00        0.00
# 25 Van Ness Building                0.00        0.00        0.00        0.00
# 30 Van Ness Building                0.00        0.00        0.00        0.00
# 311 Call Center               3323478.14  3612069.11  4127040.11  4132987.24
# 3Com Park                           0.00        0.00        0.00        0.00
#
#                                     2015        2016        2017
# 1660 Mission Street Building        0.00        0.00        0.00
# 25 Van Ness Building                0.00        0.00        0.00
# 30 Van Ness Building                0.00        0.00        0.00
# 311 Call Center               4418793.59  4640245.59  6249178.77
# 3Com Park                           0.00        0.00        0.00

# %%
important_programs = ['Patrol', 'Operations And Administration', 'Special Operations',
                      'SFPD-Recruitment And Examination Program', 'SFPD Training']

# %%
df_agg_programs = df_agg_programs.loc[important_programs]

# %%
df_tran_programs = df_agg_programs.T

# %%
df_tran_programs
# Out:
#             Patrol  Operations And Administration  Special Operations  \
# 1999  1.566657e+08                   4.110268e+07           151017.92
# 2000  1.763137e+08                   5.329274e+07           305729.53
# 2001  1.867238e+08                   5.817293e+07           163570.07
# 2002  1.947401e+08                   5.272834e+07           291461.02
# 2003  1.904606e+08                   4.906499e+07          9285482.67
# 2004  1.806452e+08                   5.071372e+07         10083238.54
# 2005  1.807123e+08                   7.997473e+07                0.00
# 2006  1.933768e+08                   9.016354e+07                0.00
# 2007  2.041555e+08                   9.958305e+07                0.00
# 2008  2.310162e+08                   1.036423e+08                0.00
# 2009  2.442172e+08                   1.014032e+08                0.00
# 2010  2.669914e+08                   1.048033e+08                0.00
# 2011  2.702060e+08                   1.082952e+08                0.00
# 2012  2.858934e+08                   1.115538e+08                0.00
# 2013  3.067614e+08                   1.155002e+08                0.00
# 2014  3.032134e+08                   1.226672e+08                0.00
# 2015  3.045171e+08                   1.339499e+08                0.00
# 2016  3.158778e+08                   1.464188e+08                0.00
# 2017  3.243342e+08                   1.549274e+08                0.00
#
#       SFPD-Recruitment And Examination Program  SFPD Training
# 1999                                1292994.89     1490869.85
# 2000                                1544261.40     1380405.97
# 2001                                1735868.52     3000961.24
# 2002                                1344727.58     2465499.89
# 2003                                1383969.78     1099537.23
# 2004                                 991255.91     1048983.57
# 2005                                      0.00      731208.16
# 2006                                      0.00      223558.12
# 2007                                      0.00     1261131.59
# 2008                                      0.00      855390.40
# 2009                                      0.00      581055.86
# 2010                                      0.00      665224.37
# 2011                                      0.00      798467.86
# 2012                                      0.00      921299.49
# 2013                                      0.00     1089277.36
# 2014                                      0.00     1007314.03
# 2015                                      0.00      951422.94
# 2016                                      0.00     1662665.82
# 2017                                      0.00      180568.82

# %%
labels = list(df_tran_programs.columns)

# %%
labels
# Out:
# ['Patrol',
#  'Operations And Administration',
#  'Special Operations',
#  'SFPD-Recruitment And Examination Program',
#  'SFPD Training']

# %%
plt.figure(figsize=(22,10))

plt.title('Important Police Programs 1999-2017')
plt.xlabel('Year')
plt.ylabel('Budget')


plt.xticks(np.arange(min(np.array(df_tran_programs.index)), max(np.array(df_tran_programs.index))+1, 
                     1.0))

for program in labels:
    plt.plot(df_tran_programs.index, np.array(df_tran_programs[program]),
         label=program)


plt.legend()
plt.show()

# %%
labels2 = labels[2:]
labels2
# Out:
# ['Special Operations',
#  'SFPD-Recruitment And Examination Program',
#  'SFPD Training']

# %%
plt.figure(figsize=(22,10))

plt.title('Important Police Programs 1999-2017')
plt.xlabel('Year')
plt.ylabel('Budget')


plt.xticks(np.arange(min(np.array(df_tran_programs.index)), max(np.array(df_tran_programs.index))+1, 
                     1.0))

for program in labels2:
    plt.plot(df_tran_programs.index, np.array(df_tran_programs[program]),
         label=program)


plt.legend()
plt.show()

# %%
df_tran_programs
# Out:
#             Patrol  Operations And Administration  Special Operations  \
# 1999  1.566657e+08                   4.110268e+07           151017.92
# 2000  1.763137e+08                   5.329274e+07           305729.53
# 2001  1.867238e+08                   5.817293e+07           163570.07
# 2002  1.947401e+08                   5.272834e+07           291461.02
# 2003  1.904606e+08                   4.906499e+07          9285482.67
# 2004  1.806452e+08                   5.071372e+07         10083238.54
# 2005  1.807123e+08                   7.997473e+07                0.00
# 2006  1.933768e+08                   9.016354e+07                0.00
# 2007  2.041555e+08                   9.958305e+07                0.00
# 2008  2.310162e+08                   1.036423e+08                0.00
# 2009  2.442172e+08                   1.014032e+08                0.00
# 2010  2.669914e+08                   1.048033e+08                0.00
# 2011  2.702060e+08                   1.082952e+08                0.00
# 2012  2.858934e+08                   1.115538e+08                0.00
# 2013  3.067614e+08                   1.155002e+08                0.00
# 2014  3.032134e+08                   1.226672e+08                0.00
# 2015  3.045171e+08                   1.339499e+08                0.00
# 2016  3.158778e+08                   1.464188e+08                0.00
# 2017  3.243342e+08                   1.549274e+08                0.00
#
#       SFPD-Recruitment And Examination Program  SFPD Training
# 1999                                1292994.89     1490869.85
# 2000                                1544261.40     1380405.97
# 2001                                1735868.52     3000961.24
# 2002                                1344727.58     2465499.89
# 2003                                1383969.78     1099537.23
# 2004                                 991255.91     1048983.57
# 2005                                      0.00      731208.16
# 2006                                      0.00      223558.12
# 2007                                      0.00     1261131.59
# 2008                                      0.00      855390.40
# 2009                                      0.00      581055.86
# 2010                                      0.00      665224.37
# 2011                                      0.00      798467.86
# 2012                                      0.00      921299.49
# 2013                                      0.00     1089277.36
# 2014                                      0.00     1007314.03
# 2015                                      0.00      951422.94
# 2016                                      0.00     1662665.82
# 2017                                      0.00      180568.82
