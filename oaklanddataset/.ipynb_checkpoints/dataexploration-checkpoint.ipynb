# %% [markdown]
# # Oakland Budget
#
# The data set is located within the dropbox folder available in slack.
# FilePath: DropBox/dswg-police-budgets/data/raw/oakland/2019-21_Adopted_Budget.csv
#
# The purpose of this notebook is to inspect and aggregate [data](https://data.oaklandnet.com/Financial/FY-2019-21-Biennial-Proposed-Budget/aeya-c8st) concerning the budget in Oakland, California.

# %% [markdown]
# ### Import Modules and read the csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('2019-21_Adopted_Budget.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46859 entries, 0 to 46858
# Data columns (total 30 columns):
# Department                            46859 non-null object
# Division                              46859 non-null object
# Dept                                  46859 non-null object
# Department Alias                      46841 non-null object
# Service Area                          46859 non-null object
# Service Area Alias                    46859 non-null object
# Fund                                  46859 non-null object
# Fund and Desc                         46859 non-null object
# Org                                   46859 non-null object
# Org and Desc                          46859 non-null object
# Project                               46859 non-null object
# Project and Desc                      46859 non-null object
# Prog                                  46859 non-null object
# Prog and Desc                         46859 non-null object
# ...

# %%
df.head(5)
# Out:
#                    Department                                    Division  \
# 0               DP010 - Mayor               DV011 - Mayor: Administration
# 1               DP010 - Mayor               DV011 - Mayor: Administration
# 2               DP010 - Mayor               DV011 - Mayor: Administration
# 3  DP020 - City Administrator  DV021 - City Administrator: Administration
# 4  DP020 - City Administrator  DV021 - City Administrator: Administration
#
#    Dept    Department Alias Service Area           Service Area Alias  \
# 0  DP01               Mayor       SA0100              Mayor's Support
# 1  DP01               Mayor       SA0100              Mayor's Support
# 2  DP01               Mayor       SA0100              Mayor's Support
# 3  DP03  City Administrator       SA0300  Administration / Operations
# 4  DP03  City Administrator       SA0300  Administration / Operations
#
#       Fund                         Fund and Desc       Org  \
# ...

# %% [markdown]
# #### Breakdowns of various departments that the budget goes towards

# %%
departments = df['Department Alias'].unique()

# %%
departments
# Out:
# array(['Mayor', 'City Administrator', 'City Clerk', 'City Attorney',
#        'Human Resources Management Department', 'City Auditor',
#        'Finance Department', 'Police Department', 'Fire Department',
#        'Oakland Public Works', 'Information Technology',
#        'Oakland Parks, Recreation & Youth Development',
#        'Oakland Public Library', 'Race & Equity',
#        'Public Ethics Commission', 'Police Commission',
#        'Department of Violence Prevention', 'Human Services',
#        'Planning & Building', 'Economic & Workforce Development',
#        'Capital Improvement Projects', 'City Council', 'Transportation',
#        'Housing & Community Development', 'Non', nan], dtype=object)

# %%
grouped = df.groupby('Department Alias')

# %% [markdown]
# ### Inspect the various subdivisions of 'Police Department' and 'Police Commission'
#
# Inside of this data set there are two different subdivisions of Police data. These are either in the Department Alias as 'Police Department' or 'Police Commision'. It is important to inspect these further to determine further subdivisions.

# %%
police_deparment = grouped.get_group('Police Department')

# %% [markdown]
# Overview of police department

# %%
police_deparment.head()
# Out:
#                      Department                                Division  Dept  \
# 104  DP1000 - Police Department  DV1010 - Office of the Chief of Police  DP14
# 105  DP1000 - Police Department  DV1010 - Office of the Chief of Police  DP14
# 106  DP1000 - Police Department  DV1010 - Office of the Chief of Police  DP14
# 107  DP1000 - Police Department  DV1010 - Office of the Chief of Police  DP14
# 108  DP1000 - Police Department  DV1010 - Office of the Chief of Police  DP14
#
#       Department Alias Service Area             Service Area Alias     Fund  \
# 104  Police Department       SA1400  Office of the Chief of Police  FD_1010
# 105  Police Department       SA1400  Office of the Chief of Police  FD_1010
# 106  Police Department       SA1400  Office of the Chief of Police  FD_1010
# 107  Police Department       SA1400  Office of the Chief of Police  FD_1010
# 108  Police Department       SA1400  Office of the Chief of Police  FD_1010
#
# ...

# %% [markdown]
# Count unique values in 'Fund and Desc' in descending order

# %%
police_deparment['Fund and Desc'].value_counts()
# Out:
# 1010 - General Fund: General Purpose                                      4936
# 2252 - Measure Z - Violence Prevention and Public Safety Act of 2014       427
# 2113 - Department of Justice - COPS Hiring                                 350
# 2411 - False Alarm Reduction Program                                       132
# 2159 - State of California Other                                            94
# 2112 - Department of Justice                                                75
# 2172 - Alameda County: Vehicle Abatement Authority                          47
# 2416 - Traffic Safety Fund                                                  40
# 2995 - Police Grants                                                        24
# 1100 - Self Insurance Liability                                             24
# 2999 - Miscellaneous Grants                                                 20
# 2152 - California Board of Corrections                                      20
# ...

# %% [markdown]
# Count unique values in 'Division' column in descending order

# %%
police_deparment['Division'].value_counts()
# Out:
# DV1080 - Bureau of Field Operations        2400
# DV1020 - Bureau of Investigation           1337
# DV1070 - Bureau of Field Operations New     757
# DV1030 - Bureau of Services                 722
# DV1010 - Office of the Chief of Police      539
# DV1060 - Bureau of Administration           533
# Name: Division, dtype: int64

# %% [markdown]
# ### Inspect Police Commision Category

# %%
police_commission  = grouped.get_group('Police Commission')

police_commission.head()
# Out:
#                      Department Division  Dept   Department Alias  \
# 382   DP660 - Police Commission   DV_661  DP07  Police Commission
# 383   DP660 - Police Commission   DV_662  DP07  Police Commission
# 384   DP660 - Police Commission   DV_663  DP07  Police Commission
# 3334  DP660 - Police Commission   DV_661  DP07  Police Commission
# 3335  DP660 - Police Commission   DV_662  DP07  Police Commission
#
#      Service Area              Service Area Alias     Fund  \
# 382        SA0700               Police Commission  FD_1010
# 383        SA0701  Community Police Review Agency  FD_1010
# 384        SA0702               Inspector General  FD_1010
# 3334       SA0700               Police Commission  FD_1010
# 3335       SA0701  Community Police Review Agency  FD_1010
#
#                              Fund and Desc       Org  \
# 382   1010 - General Fund: General Purpose  OR_66111
# 383   1010 - General Fund: General Purpose  OR_66211
# ...

# %% [markdown]
# Count unique values in 'Fund and Desc' in descending order

# %%
police_commission['Fund and Desc'].value_counts()
# Out:
# 1010 - General Fund: General Purpose    76
# Name: Fund and Desc, dtype: int64

# %% [markdown]
# Count unique cells in 'Org and Desc'

# %%
police_commission['Org and Desc'].value_counts()
# Out:
# 66211 - Community Police Review Agency    47
# 66111 - Police Commission                 14
# 66311 - Inspector General                 11
# 02211 - Citizens' Police Review Board      4
# Name: Org and Desc, dtype: int64

# %% [markdown]
# Count unqiue cells in 'Service Area Alias

# %%
police_commission['Service Area Alias']
# Out:
# 382                   Police Commission
# 383      Community Police Review Agency
# 384                   Inspector General
# 3334                  Police Commission
# 3335     Community Police Review Agency
#                       ...
# 37873                 Police Commission
# 37874    Community Police Review Agency
# 37875                 Inspector General
# 39303    Community Police Review Agency
# 42767    Community Police Review Agency
# Name: Service Area Alias, Length: 76, dtype: object

# %%
aggregated_data = df.groupby(['Department Alias'])[['FY18-19 \nMidcycle Adopted Ongoing', 'FY18-19 \nMidcycle Adopted One Time', 'FY18-19 \nMidcycle Adopted Total', 'FY19-20 \nBiennial Working Ongoing','FY19-20 \nBiennial Working One Time','FY19-20 \nBiennial Working Total','FY20-21 \nBiennial Working Ongoing','FY20-21 \nBiennial Working One Time', 'FY20-21 \nBiennial Working Total']].agg('sum')

# %%
aggregated_data
# Out:
#                                                FY18-19 \nMidcycle Adopted Ongoing  \
# Department Alias
# Capital Improvement Projects                                           65546259.0
# City Administrator                                                     18962172.0
# City Attorney                                                          18615221.0
# City Auditor                                                            2064905.0
# City Clerk                                                              6841790.0
# City Council                                                            5522030.0
# Department of Violence Prevention                                       1129204.0
# Economic & Workforce Development                                       27620179.0
# Finance Department                                                    776626557.0
# Fire Department                                                       169873263.0
# ...

# %% [markdown]
# #### Furthur aggregation of the data to look only at the total budgets between 2018 and 2021

# %%
final_budget = df.groupby(['Department Alias'])[['FY18-19 \nMidcycle Adopted Total', 
                                                 'FY19-20 \nBiennial Working Total',
                                                 'FY20-21 \nBiennial Working Total']].agg('sum')

# %%
final_budget
# Out:
#                                                FY18-19 \nMidcycle Adopted Total  \
# Department Alias
# Capital Improvement Projects                                         66201524.0
# City Administrator                                                   18912172.0
# City Attorney                                                        18615221.0
# City Auditor                                                          2064905.0
# City Clerk                                                            7259799.0
# City Council                                                          5522030.0
# Department of Violence Prevention                                     1129204.0
# Economic & Workforce Development                                     43306380.0
# Finance Department                                                  777351557.0
# Fire Department                                                     169822143.0
# ...
